# %% [markdown]
# ## Introduction to Python programming:
# <img src='https://miro.medium.com/max/1027/1*Ud_bNdeWPf4iN1EcydaDFA.png' height=300 width=400>
#
# ###Print an output:
#
# 1. C
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
# 2. C++
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
# 3. JAVA
#
# ![image.png](data:image/png;base64,...)

# %%
print('python is so cool')
# Out:
# python is so cool

# %%
print('hello everyone')
# Out:
# hello everyone

# %%
print("hello faraz")
# Out:
# hello faraz

# %%
print('hello faraz')
# Out:
# hello faraz

# %%
print("10+10")
# Out:
# 10+10

# %%
print(2+3)
# Out:
# 5

# %%
print(10+10)
# Out:
# 20

# %%
Print("4+10")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8cad0d1c4ff1> in <module>
# ----> 1 Print("4+10")
#
# NameError: name 'Print' is not defined

# %%
print(4*9)
# Out:
# 36

# %%
print('hello')
# Out:
# hello

# %%
print('hello',end='#')
print('hina',end='@')
# Out:
# hello#hina@

# %%
print(8-5)
# Out:
# 3

# %%
print("10")
# Out:
# 10
